# %%
SELECT CURRENT_VERSION();

# %%
%%sql -r dataframe_1
SELECT CURRENT_ROLE();

# %%
%%sql -r dataframe_4
USE ROLE ACCOUNTADMIN;

# %%
%%sql -r dataframe_9
SELECT CURRENT_USER();

# %%
%%sql -r dataframe_5
GRANT SELECT ON ALL TABLES IN SCHEMA GITHUB_RAW.GITHUB TO ROLE ACCOUNTADMIN;

# %%
%%sql -r dataframe_2
DESCRIBE TABLE GITHUB_RAW.GITHUB.USER;

# %%
%%sql -r dataframe_3
DESCRIBE TABLE GITHUB_RAW.GITHUB.REPOSITORY;

# %%
%%sql -r dataframe_6
DROP SCHEMA GITHUB_ANALYTICS.MARTS;

# %%
%%sql -r dataframe_7
DROP SCHEMA GITHUB_STAGING.STAGING;

# %%
%%sql -r dataframe_8
USE ROLE ACCOUNTADMIN;
GRANT ROLE DBT_ROLE TO USER JACK2000;
-- then
USE ROLE DBT_ROLE;
DROP SCHEMA GITHUB_STAGING.FIVETRAN_STAGING;
DROP SCHEMA GITHUB_STAGING.FIVETRAN_MARTS;

# %%
%%sql -r dataframe_10
DESCRIBE TABLE GITHUB_RAW.GITHUB.COMMIT;
